# %% [markdown]
# # Summary
#
# ## Overview
#
# 1. Simple yet powerful ML algorithm
# 2. Used for <u>Classification tasks based on features</u>
#
# ## Naive Assumption
# 1. Assumes features are independent of each other, therefore called <u>Naive</u>
#
# ## Algorithm Workflow
# 1. Calculates probability of each class given the input features
# 2. Selects class with highest probability as predicted class
# 3. Uses Bayes' theorem to update probability based on observed features
#
# ## Key Features
# 1. Simple and computationally efficient
# 2. Particularly effective for text classification tasks like <u>spam detection and document categorization</u>.
# 3. Performs well in practice, even with the "naive" independence assumption.
#
# ## Applications
#
# 1. Widely used in various applications due to its speed, simplicity, and effectiveness
# 2. Especially <u>suitable for high-dimensional data with many features</u>
#
# ## A Very Basic Example
#
# Suppose we have a dataset of emails, where each email is represented by two features:
# 1. the presence of the word "lottery" (0 or 1)
# 2. the presence of the word "free" (0 or 1)
#
# The target variable is whether the email is spam (1) or not spam (0).
#
# | Email ID | Lottery | Free | Spam |
# |----------|---------|------|------|
# | 1        | 1       | 0    | 1    |
# | 2        | 0       | 1    | 1    |
# | 3        | 0       | 0    | 0    |
# | 4        | 1       | 1    | 1    |
# | 5        | 0       | 0    | 0    |
#
# Now, let's say we receive a new email with the following features: "lottery" (1) and "free" (0).
#
# Using Naive Bayes, we want to predict whether this new email is spam or not spam.
#
# **The algorithm works as follows:**
#
# 1. <u>Calculate Class Probabilities:</u>
#
# Compute the probability of spam and not spam emails in the dataset. In this case, P(Spam) = 3/5 and P(Not Spam) = 2/5.
#
# 2. <u>Calculate Feature Probabilities:</u>
#
# For each feature (lottery and free), compute the conditional probabilities of the feature given the class (spam or not spam).
#
# For example, P(Lottery=1 | Spam) = 2/3 (as 2 out of 3 spam emails contain "lottery").
# Similarly, P(Lottery=1 | Not Spam) = 1/2 and P(Free=0 | Not Spam) = 1.
#
# 3. <u>Calculate Posterior Probabilities:</u>
#
# Use Bayes' theorem to calculate the posterior probabilities of each class given the features.
#
# For the new email, calculate P(Spam | Lottery=1, Free=0) and P(Not Spam | Lottery=1, Free=0) using the conditional probabilities and class probabilities.
#
# 4. <u>Predict the Class:</u>
#
# Choose the class with the highest posterior probability as the predicted class.
#
# In this case, if P(Spam | Lottery=1, Free=0) > P(Not Spam | Lottery=1, Free=0), then predict spam; otherwise, predict not spam.
#
# 5. <u>Result:</u>
#
# Based on the computed probabilities, we predict whether the new email is spam or not spam.
# This is a basic example of how Naive Bayes works for classification tasks. It's simple yet effective, especially for text classification problems like spam detection.

# %% [markdown]
# # 1. A Really Dumb Spam Filter
#
# - Consider 2 events:
#   1. S : "the message is spam"
#   2. B : "the message contains word `bitcoin`
#
# - According to Bayes' theorem : Probability of a message is spam when message contains word bitcoin is -
#   $$ P(S|B) = \frac{P(B|S).P(S)}{P(B|S).P(S) + P(B|¬S).P(¬S)}$$
#
# - This simply represents the proportion of bitcoin messages that are spam.
#
# - **Assumption**
#   1. We have a sample data of known 'spam' and 'not spam' - thus we can estimate
#      $ P(B|S)$ and $P(B|¬S)$
#   3. Any new message has equal probability of being 'spam' or 'not spam' - thus $P(S) = P(¬S) = 0.5$
#
#      So, from Bayes' theorem:
#    >  $$ P(S|B) = \frac{P(B|S).P(S)}{P(B|S).P(S) + P(B|¬S).P(¬S)}$$
#    >  $$ P(S|B) = \frac{P(B|S).P(S)}{P(S).(P(B|S) + P(B|¬S)}$$
#    >  $$ P(S|B) = \frac{P(B|S)}{P(B|S) + P(B|¬S)}$$
#
#   **Example**
#   if 50% of spam messages have the word bitcoin (P(B|S) = 0.5) but only 1% of nonspam messages do (P(B|-S) = 0.01), then the probability that any given bitcoin-containing email is spam is:
# $$ P(S|B) = \frac{0. 5}{0. 5 + 0. 01} = 0.98 $$

# %% [markdown]
# # 2. A More Sophisticated Spam Filter
# - Imagine we have a vocabulary of words $w_{1}, w_{2}, ... w_{n}$
#   > Event $X_{i}$ means ' the message contains $w_i$ '
# - Imagine **we have sample data** of spam and non-spam mesages from where we know:
#   > Probability that a spam message contains word $w_{i}$ is $P(X_{i}|S)$
#   > and
#   > Probability that a non-spam message contains word $w_{i}$ is $P(X_{i}|-S)$
# - Naive Bayes assumes that **presence of each word is independent of each other** such that (Extreme Assumption):
#   > $P(X_{1} = x_{1}, . . . ,X_{n} = x_{n}|S) = P(X_{1} = x_{1}|S) ×⋯× P(X_{n} = x_{n}|S)$
#   - This is an extreme assumption.
#   - Imagine we have 100 spam messages.
#   - Out of it, 50 spam messages contain spam word 'bitcoin' and 50 messages contain spam word 'rolex'.
#   - No spam message contains both words together thus probability of spam message to contain both words becomes should be 0.
#   - But as both words are considered independent occuring, it comes from formula:
#   > $P(X_{1} = 1, X_{2} = 1|S) = P(X_{1} = 1|S) × P(X_{2} = 1|S)$
#   > $P(X_{1} = 1, X_{2} = 1|S) = 0.5 × 0.5 = 0.25$
#   > Despite the unrealisticness of this assumption, this model often performs well and has historically been used in actual spam filters.
#
# - Using Bayes' theorem we can compute $P(S|X=x)$
#   > $$ P(S|X=x_{i}) = \frac{P(x_{i}|S)}{P(x_{i}|S) + P(x_{i}|¬S)}$$
#   > To compute the probability of message to be spam if it has list of words $x_{1}, x_{2},..., x_{n}$ multiply individual probability estimates
#
# - **Problem of Underflow**: we want to avoid multiplying lots of probabilities together, to prevent a problem called underflow, in which computers don’t deal well with floating-point numbers that are too close to 0. Computer will multiply many very small numbers (e.g. 0.0001 x 0.00025 x ...) and eventually after many multiplications it will reduce to 0
#   > So, to avoid this we use - $log(ab) = log a + log b$ and $exp(log x) = x$
#   > It is floating-point-friendlier
#
# - **Problem of 0 probability of any word**:
#   > **How do we calculate $P(x_{i}|S)$ and $P(x_{i}|-S)$?** -- From sample data -- simply as the fraction of spam messages containing the word wi.
#   > **Problem in this?** - Imagine that in our training set the vocabulary word data only occurs in nonspam messages. Then we’d estimate P(data|S) = 0. The result is that our Naive Bayes classifier would always assign spam probability 0 to any message containing the word data, even a message like “data on free bitcoin and authentic rolex watches.”
#   > **How to solve this?** -- we’ll choose a pseudocount—k—and estimate the probability of seeing the $i^{th}$ word in a spam message as:
# $$ P (Xi|S) = \frac{k + number\_of\_spams\_containing\_wi}{2k + number\_of\_spams} $$
#   > We do similarly for $P(Xi|¬S)$. That is, when computing the spam probabilities for the $i^{th}$ word, we assume we also saw k additional nonspams containing the word and k additional nonspams not containing the word.
#   > For example, if 'data' occurs in 0/98 spam messages, and if k is 1, we estimate P(data|S) as 1/100 = 0.01, **which allows our classifier to still assign some nonzero spam probability** to messages that contain the word 'data'.

# %% [markdown]
# # 3.Implementation

# %% [markdown]
# ## Without functions - Basic code
# > 1. We have messages in a named tuple format of (text: str, is_spam: bool)
# > 2. First we will tokenize our texts and keep it in a dict of {text: List[words]}
# > 3. Then we will check if the messgae is_spam - Count no. of spam messages, no. of ham messages, frequency of tokens in spam messages, frequency of tokens in ham messages
# > 4. Calculate probability of each token in spam and ham messages

# %%
# Our training data
from typing import NamedTuple
class Message(NamedTuple):
    text: str
    is_spam: bool
    
messages = [Message(text = 'Congratulations Tanu, you have won 0.5 BTC. Click here to claim your BTC now', is_spam = True),
            Message(text = 'Hey Tanu, you won a new gift! Click here to buy your Rolex now', is_spam = True),
            Message(text = 'Dear Tanu, this mail is a reply to your query', is_spam = False)]

# Let's print the class
for message in messages:
    print(f"{message.text=}")
    print(f"{message.is_spam=}")
# Out:
# message.text='Congratulations Tanu, you have won 0.5 BTC. Click here to claim your BTC now'
# message.is_spam=True
# message.text='Hey Tanu, you won a new gift! Click here to buy your Rolex now'
# message.is_spam=True
# message.text='Dear Tanu, this mail is a reply to your query'
# message.is_spam=False

# %%
# Tokenize the training data

import re

tokens_dict = {}
for message in messages:
    text = message.text.lower()
    words = re.findall("[a-z0-9']+", text) # Returns a list of all non-overlapping matches in the string
    words = set(words)
    tokens_dict[message] = words

# Let's print the dict of tokens
print(f"{tokens_dict=}")
# Out:
# tokens_dict={Message(text='Congratulations Tanu, you have won 0.5 BTC. Click here to claim your BTC now', is_spam=True): {'click', 'now', 'won', 'btc', 'have', 'tanu', '5', 'you', '0', 'your', 'congratulations', 'to', 'here', 'claim'}, Message(text='Hey Tanu, you won a new gift! Click here to buy your Rolex now', is_spam=True): {'hey', 'new', 'click', 'won', 'buy', 'tanu', 'gift', 'you', 'your', 'rolex', 'a', 'now', 'to', 'here'}, Message(text='Dear Tanu, this mail is a reply to your query', is_spam=False): {'is', 'mail', 'dear', 'tanu', 'reply', 'your', 'a', 'to', 'this', 'query'}}

# %%
# Counts

from collections import defaultdict

spam_messages = 0
ham_messages = 0
spam_token_counts = defaultdict(int)
ham_token_counts = defaultdict(int)

for message in messages:
    if message.is_spam:
        spam_messages +=1 
        for word in tokens_dict[message]:
            spam_token_counts[word] +=1
    else:
        ham_messages +=1
        for word in tokens_dict[message]:
            ham_token_counts[word] +=1

# Let's print the token counts in spam and ham

print(spam_token_counts)
print(ham_token_counts)
# Out:
# defaultdict(<class 'int'>, {'click': 2, 'now': 2, 'won': 2, 'btc': 1, 'have': 1, 'tanu': 2, '5': 1, 'you': 2, '0': 1, 'your': 2, 'congratulations': 1, 'to': 2, 'here': 2, 'claim': 1, 'hey': 1, 'new': 1, 'buy': 1, 'gift': 1, 'rolex': 1, 'a': 1})
# defaultdict(<class 'int'>, {'is': 1, 'mail': 1, 'dear': 1, 'tanu': 1, 'reply': 1, 'your': 1, 'a': 1, 'to': 1, 'this': 1, 'query': 1})

# %% [markdown]
# ## Naive Bayes' Classifier

# %% [markdown]
# 1. Tokenize
# 2. Define type of training data as Namedtuple
# 3. Define classifier
#    > 1. init method
#    > 2. training by iteration
#    > 3. prob calculation from (k+spam_with_w_counts)/(2k+total_spam_counts)
#    > 4. predict probabilty of message being spam considering all tokens are independent to each other

# %%
#Tokenize
from typing import Set, Iterable, Tuple
import re, math
from collections import defaultdict


def tokenize(text:str) -> Set[str]:
    text = text.lower()
    all_words = re.findall("[a-z0-9']+", text)
    return set(all_words)

assert tokenize("Data science is science") == {"data", "science", "is", "science"}


# Define type for training data
# For named tuple type we use class
from typing import NamedTuple
class Message(NamedTuple):
    text: str
    is_spam: bool


# Classifer needs track of tokens, counts, labels etc
# For this we create a class
# Initialize all counters to 0

class NaiveBayesClassifier:
    def __init__(self, k: float = 0.5) -> None:
        self.k = k # smoothening factor

        self.tokens: Set[str] = set()
        self.token_spam_counts: Dict[str, int] = defaultdict(int)
        self.token_ham_counts:  Dict[str, int] = defaultdict(int)
        self.spam_messages = self.ham_messages = 0

   
    # Method to train a bunch of messages
    # Increment spam and ham message counts
    # tokenize spam and ham message and keep count track in dicts
    def train(self, messages: Iterable[Message]) -> None:

        # Increment spam and ham counts
        for message in messages:
            if message.is_spam:
                self.spam_messages +=1
            else:
                self.ham_messages +=1

            # Increment word counts
            for token in tokenize(message.text):
                self.tokens.add(token)
                if message.is_spam:
                    self.token_spam_counts[token] +=1
                else:
                    self.token_ham_counts[token] +=1

    # To predict P(spam|token) using Bayes' theorem
    # We need P(token|spam) and P(token|ham)
    # Create private helper function for this

    def _probabilities(self, token: str) -> Tuple[float, float]:
        """
        returns P(token|spam) and P(token|ham)
        """
        spam = self.token_spam_counts[token] # number of 'tokens' in spam messages
        ham = self.token_ham_counts[token]   # number of 'tokens' in ham messages

        p_token_spam = (spam + self.k) / (self.spam_messages + 2 * self.k)
        p_token_ham = (ham + self.k) /(self.ham_messages + 2* self.k)
        return p_token_spam, p_token_ham
        
    # Finally predict using log and exp method instead of multiplication of small p's
   

    def predict(self, text: str) -> float:
        text_tokens = tokenize(text)
        log_p_if_spam = log_p_if_ham = 0.0

        # Iterate through each word in our vocab 

        for token in self.tokens:
            prob_if_spam, prob_if_ham = self._probabilities(token)

            # If 'token' appears in the message,
            # Add log prob of seeing it
            if token in text_tokens:
                log_p_if_spam += math.log(prob_if_spam)
                log_p_if_ham += math.log(prob_if_ham)

            # Otherwise add the log probability of not seeing it
            else:
                log_p_if_spam  += math.log(1.0 - prob_if_spam)
                log_p_if_ham += math.log(1.0 - prob_if_ham)

        prob_if_spam = math.exp(log_p_if_spam)
        prob_if_ham = math.exp(log_p_if_ham)
        return prob_if_spam/(prob_if_spam+prob_if_ham)

# %% [markdown]
# ### Testing

# %%
# Sample test data

messages = [Message("spam rules", is_spam=True),
Message("ham rules", is_spam=False),
Message("hello ham", is_spam=False)]

model = NaiveBayesClassifier(k = 0.5)
model.train(messages)

# Let's check what we got
print(f" {model.k =},\n {model.tokens=},\n {model.token_spam_counts=},\n {model.token_ham_counts=},\n {model.spam_messages =},\n {model.ham_messages=} ")
# Out:
#  model.k =0.5,
#  model.tokens={'spam', 'hello', 'ham', 'rules'},
#  model.token_spam_counts=defaultdict(<class 'int'>, {'spam': 1, 'rules': 1}),
#  model.token_ham_counts=defaultdict(<class 'int'>, {'ham': 2, 'rules': 1, 'hello': 1}),
#  model.spam_messages =1,
#  model.ham_messages=2

# %%
# Let's make the prediction now

text = "hello spam"
model.predict(text)
# Out:
# 0.8350515463917525

# %%
#Let's calculate it by hand 

text = "hello spam"

#probability of various words be present in spam and text
prob_if_spam =  [
(1 + 0.5) / (1 + 2 * 0.5), # "spam" (present in text)  
1 - (0 + 0.5) / (1 + 2 * 0.5), # "ham" (not present)  
1 - (1 + 0.5) / (1 + 2 * 0.5), # "rules" (not present)  
(0 + 0.5) / (1 + 2 * 0.5) # "hello" (present)
]

#probability of various words be present in ham and text
prob_if_ham =  [
(0+0.5)/(2*0.5 + 2),  #'spam'(present)  
(1- (2+0.5) / (2*0.5 + 2)),  #'ham'(not present)    
(1- (1+0.5) / (2*0.5 + 2)), #'rules'(not present)   
(1+0.5)/(2*0.5 + 2) #'hello'(present in text)   
]

# %%
p_if_spam = math.exp(sum(math.log(p) for p in prob_if_spam))
p_if_ham = math.exp(sum(math.log(p) for p in prob_if_ham))

# Should be about 0.83
assert model.predict(text) == p_if_spam / (p_if_spam + p_if_ham)

# %% [markdown]
# # 4. Using our model on real data

# %%
# Download and unpack dataset

import requests # To request file from url
import tarfile # To open files in .tar format
from io import BytesIO # So we can treat bytes as a file.


BASE_URL = "https://spamassassin.apache.org/old/publiccorpus/"
FILES = ["20021010_easy_ham.tar.bz2",
         "20021010_hard_ham.tar.bz2",
         "20021010_spam.tar.bz2"]

OUTPUT_DIR = 'spam_data' # This is where data will be downloaded

# Unzip all three FILES
for filename in FILES:
    content = requests.get(f"{BASE_URL}/{filename}").content
    fin = BytesIO(content)
    with tarfile.open(fileobj = fin, mode = 'r:bz2') as tf:
        tf.extractall(OUTPUT_DIR)

# %% [markdown]
# - After downloading the data you should have three folders: spam, easy_ham, and hard_ham.
#
# - Each folder contains many emails, each contained in a single file.
#
# - To keep things really simple, we’ll just look at the subject lines of each email.
#
# - How do we identify the subject line? When we look through the files, they all seem to <u>start with “Subject:”</u>. So we’ll look for that.

# %%
from typing import List
import glob # Helps in searching for files matching a specified pattern
import re

# Create a Message type class
from typing import NamedTuple
class Message(NamedTuple):
    text: str
    is_spam: bool

# spam_data is directory where files are present
# * is the wildcard character used to find path patterns
path = 'spam_data/*/*'

# Create emoty list of Message type
data: List[Message] = []

for filename in glob.glob(path):
    is_spam = "ham" not in filename # Set 1 if spam and 0 if ham
    with open(filename, errors = 'ignore') as email_file:
        for line in email_file:
            if line.startswith("Subject:"):
                subject = line.lstrip("Subject: ") 
                data.append(Message(subject, is_spam))
                break
data
# Out:
# [Message(text='Friend, Copy ANY DVD or Playstation Game with this software......\n', is_spam=True),
#  Message(text='5% Guaranteed for Eight Years\n', is_spam=True),
#  Message(text='Congratulations! You Get a Free Handheld Organizer!\n', is_spam=True),
#  Message(text='One of a kind Money maker! Try it for free!\n', is_spam=True),
#  Message(text='Online Doctors will fill your Viagra Prescription Now!!!                QEEB\n', is_spam=True),
#  Message(text='Take your Marketing to the Next Level\n', is_spam=True),
#  Message(text='One Sale - Three Commission Streams\n', is_spam=True),
#  Message(text='Find Peace, Harmony, Tranquility, And Happiness Right Now!\n', is_spam=True),
#  Message(text='ADV: Extended Auto Warranties Here                                                    undoc\n', is_spam=True),
#  Message(text='Definitely the answer many have been waiting for!!\n', is_spam=True),
#  Message(text="ave $100's, maybe $1,000's with No Lender's Fees. Click here!\n", is_spam=True),
#  Message(text='Get the Computer Skills you need - Free\n', is_spam=True),
#  Message(text='[WM] CEVIRI YAZILIMLARI\n', is_spam=True),
#  Message(text='Let me know what you think!32482\n', is_spam=True),
#  Message(text='International calls for only 33 cents per minute with no subscription\n', is_spam=True),
#  Message(text='Garden Ornaments | ppu\n', is_spam=True),
#  Message(text='A marketplace where lenders compete for your business LFHLXHU\n', is_spam=True),
#  Message(text='Cheap Fags\n', is_spam=True),
#  Message(text='Hey, rates are low. What are you waiting for?\n', is_spam=True),
#  Message(text='One of a kind Money maker! Try it for free!\n', is_spam=True),
#  Message(text='=?iso-2022-jp?B?GyRCJDckOCRfJEgkYiRiJE4lMyVpJVwlbCE8JTclZyVzGyhK?=\n', is_spam=True),
#  Message(text='[ILUG-Social] Lose 22.5lbs in 3 weeks!\n', is_spam=True),
#  Message(text='Outstanding Opportunities for "Premier Producers"\n', is_spam=True),
#  Message(text='Re: girls\n', is_spam=True),
#  Message(text='Attn:Targeted email addresses\n', is_spam=True),
#  Message(text='Your eBay account is about to expire!\n', is_spam=True),
#  Message(text='=?iso-2022-jp?B?GyRCJDckOCRfJEgkYiRiJE4lMyVpJVwlbCE8JTclZyVzGyhK?=\n', is_spam=True),
#  Message(text='Act Now - Reach Hundreds of Prospects\n', is_spam=True),
#  Message(text='Relationship\n', is_spam=True),
#  Message(text='Re: PROTECT YOUR COMPUTER,YOU NEED SYSTEMWORKS!    COXR\n', is_spam=True),
#  Message(text='One of a kind Money maker! Try it for free!\n', is_spam=True),
#  Message(text='NEU IM HANDEL! K1-Ausgabe Nr.66\n', is_spam=True),
#  Message(text='FBI & IRS seized goods at 99% off! Police Auctions!\n', is_spam=True),
#  Message(text='RE: Important Information Concerning Your Bank Account \n', is_spam=True),
#  Message(text='[ILUG-Social] Poker for money againts real players\n', is_spam=True),
#  Message(text='!Gorgeous,Custom Websites - $399 Complete! (4156cumG9-855YQKc5@17)\n', is_spam=True),
#  Message(text='wives and girlfriends cheating and whoring around \n', is_spam=True),
#  Message(text='Ou Wei Lighting,Nights Will Be Lightening!\n', is_spam=True),
#  Message(text='The best possible mortgage\n', is_spam=True),
#  Message(text='[ILUG] Re: This is NO JOKE! Speed up your CPU for under $30!\n', is_spam=True),
#  Message(text='Re: Here is your Free Access\n', is_spam=True),
#  Message(text='3 Cd Package: 300 Million Email Addresses + 1.5 Mil Fax Numbers $99.95\n', is_spam=True),
#  Message(text='you can watch me\n', is_spam=True),
#  Message(text='Up to $1,500.00 Part time                         22311\n', is_spam=True),
#  Message(text='Let us find the right mortgage lender for you      AFPE\n', is_spam=True),
#  Message(text='HOME REPS WANTED-FORTUNE 500 COMP HIRING\n', is_spam=True),
#  Message(text='MSNBC: Rates Hit 35 year Low 4.75% ...12021\n', is_spam=True),
#  Message(text='Re: Adult Classifieds\n', is_spam=True),
#  Message(text='Term Insurance Is Out\n', is_spam=True),
#  Message(text='GET IN AT THE TOP!\n', is_spam=True),
#  Message(text='Get $100 Free - Beat the House at Royal Vegas!\n', is_spam=True),
#  Message(text='HELP WANTED.  WORK FROM HOME REPS.\n', is_spam=True),
#  Message(text='PS se odrekao Slobodana Milosevica\n', is_spam=True),
#  Message(text='Re: Want to go on a date?\n', is_spam=True),
#  Message(text='Industry Forum #136\n', is_spam=True),
#  Message(text='Get out of debt quick!                                        4179uKlj5-057SXua1524UHkC5-900-28\n', is_spam=True),
#  Message(text='Dont waste your TIME!!! Why?\n', is_spam=True),
#  Message(text='Powerball Results Saturday September 14, 2002 Estimated Jackpot $100 Million\n', is_spam=True),
#  Message(text='MAKE MONEY GIVING AWAY FREE STUFF!\n', is_spam=True),
#  Message(text='ANTICAIPTING TO HEARING FROM YOU SOON.\n', is_spam=True),
#  Message(text='Everybody Gets Paid - No Recruiting Needed\n', is_spam=True),
#  Message(text='Low Price Tobacco\n', is_spam=True),
#  Message(text='CIGARETTES WHOLESALE!       HYWWZZLZD\n', is_spam=True),
#  Message(text='Introducing Chase Platinum for Students with a 0% Introductory APR\n', is_spam=True),
#  Message(text='Mothers you want to fuck\n', is_spam=True),
#  Message(text="Newsletter Coach'Invest - Septembre 2002\n", is_spam=True),
#  Message(text='Pics for you\n', is_spam=True),
#  Message(text='Boost Your Cell Signal ...10782\n', is_spam=True),
#  Message(text='[ILUG] Create a PAYCHECK with your COMPUTER and Enjoy Cheap ISP & shopping Discount.\n', is_spam=True),
#  Message(text='Friend,Instantly Copy ANY DVD or Playstation Game with this software......\n', is_spam=True),
#  Message(text='Partnership.\n', is_spam=True),
#  Message(text='We Build The Internet.  WebXperts.com  (Design / Programming / Consultation)\n', is_spam=True),
#  Message(text='URGENT BUSINESS ASSISTANCE.\n', is_spam=True),
#  Message(text='[ILUG] Discount Fags\n', is_spam=True),
#  Message(text='[ILUG] ilug,Bigger, Fuller Breasts Naturally In Just Weeks\n', is_spam=True),
#  Message(text='FORTUNE 500 COMPANY HIRING, AT HOME REPS.\n', is_spam=True),
#  Message(text='[ILUG] BUSINESS\n', is_spam=True),
#  Message(text='MULTIPLY YOUR CUSTOMER BASE!\n', is_spam=True),
#  Message(text='[ILUG-Social] Best Replica Goods - Best Prices\n', is_spam=True),
#  Message(text="Join the Web's Hottest & Fastest Growing Community                     11.70\n", is_spam=True),
#  Message(text='lim Factors - A totally new approach to weight loss\n', is_spam=True),
#  Message(text='Paperless Publishing is Here and Now\n', is_spam=True),
#  Message(text='PS se odrekao Slobodana Milosevica\n', is_spam=True),
#  Message(text='[ILUG] re: popular .BIZ and .COM extensions for only $14.95\n', is_spam=True),
#  Message(text='Fw: NORTON SYSTEMWORKS 2002 FINAL CLEARANCE SALE!           DJHL\n', is_spam=True),
#  Message(text='Financial Power You Can Depend On\n', is_spam=True),
#  Message(text='May I have a moment of your Time PLEASE\n', is_spam=True),
#  Message(text='aint.org\n', is_spam=True),
#  Message(text='Funds Investment\n', is_spam=True),
#  Message(text='Re: zzzz@example.com\n', is_spam=True),
#  Message(text='hape up for summer now\n', is_spam=True),
#  Message(text='Remeber me?\n', is_spam=True),
#  Message(text='.Message report from your contact page....//ytu855 rkq\n', is_spam=True),
#  Message(text='Market Internet Access - No Investment Needed \n', is_spam=True),
#  Message(text='ADV: Promote Your Website!\n', is_spam=True),
#  Message(text='Get the money you need while mortgage rates are down.\n', is_spam=True),
#  Message(text='EIN News - FREE Trial\n', is_spam=True),
#  Message(text='ADV: Extended Auto Warranties Here iubrq\n', is_spam=True),
#  Message(text='Claim a Free $25 Kmart(R) Gift Card!\n', is_spam=True),
#  Message(text='WWW Form Submission\n', is_spam=True),
#  Message(text='[ILUG-Social] URGENT ASSISTANT NEEDED\n', is_spam=True),
#  Message(text="UK's Leading PC Specialist\n", is_spam=True),
#  Message(text='ADV: Extended Auto Warranties Here                                                   aanfh\n', is_spam=True),
#  Message(text='Play a Hilarious Phone Prank\n', is_spam=True),
#  Message(text='YOUR ACCOUNT HAS BEEN CLOSED!\n', is_spam=True),
#  Message(text='BUSINESS PARTNERSHIP(URGENT/CONFIDENTIAL)\n', is_spam=True),
#  Message(text='Get a FREE Bottle of Wine & Tasting Kit\n', is_spam=True),
#  Message(text='Welcome to the concept of RESIDUAL Income!\n', is_spam=True),
#  Message(text='<---- FREAK ME ---->\n', is_spam=True),
#  Message(text='---> Undervalued Company\n', is_spam=True),
#  Message(text='Please help Home Entertainment Companies with Survey - Win a DVR!\n', is_spam=True),
#  Message(text='re: domain registration savings\n', is_spam=True),
#  Message(text='[WM] zr dileriz\n', is_spam=True),
#  Message(text='zzzz, do we have your money?\n', is_spam=True),
#  Message(text='Hosting from ?6.50 per month\n', is_spam=True),
#  Message(text='Congratulations on Your 6 New Signups\n', is_spam=True),
#  Message(text='Guaranteed Best Mortgage Rate\n', is_spam=True),
#  Message(text='Re: SYSTEMWORKS CLEARANCE SALE_LIMITED QUANTITIES_ONLY $29.99 TJ\n', is_spam=True),
#  Message(text='A must have for "Gadget" lovers 7134-4\n', is_spam=True),
#  Message(text='zzzz,All New! Breast Enhancement\n', is_spam=True),
#  Message(text='Attn: PROTECT YOURSELF AGAINST HARMFUL VIRUSES! SONLSNAIK\n', is_spam=True),
#  Message(text='[ILUG] From the desk of : George Osawa\n', is_spam=True),
#  Message(text='=?GBK?B?U3VuZnJvbSBsaWdodGluZyDE+rXEwvrS4srHztLDx9e3x/O1xMS/seo=?=\n', is_spam=True),
#  Message(text='iiu.taint.org\n', is_spam=True),
#  Message(text='FORTUNE 500 WORK AT HOME REPS NEEDED!\n', is_spam=True),
#  Message(text='Vacation Time,House need work,Behind in Bills? Refinance while rates are low\n', is_spam=True),
#  Message(text='Email Marketing\n', is_spam=True),
#  Message(text='[ILUG] Seeking Your Partnership\n', is_spam=True),
#  Message(text='(_) Increase Your Sales!!!!\n', is_spam=True),
#  Message(text="** You're approved. **\n", is_spam=True),
#  Message(text='Please help Home Entertainment Companies with Survey - Win a DVR!\n', is_spam=True),
#  Message(text='Half Price Cigarettes and Tobacco\n', is_spam=True),
#  Message(text='HELP WANTED.  WORK FROM HOME REPS.\n', is_spam=True),
#  Message(text='Earn $139,000 a year as a DAY TRADER!\n', is_spam=True),
#  Message(text="Unleash your PC's Multimedia POWER at 70% off retail!\n", is_spam=True),
#  Message(text='are you in the mood             XGHTMTGGC\n', is_spam=True),
#  Message(text='[scoop] ....It is not my fault. .- vwiid\n', is_spam=True),
#  Message(text='Incredible Pictures!!!!!!!!\n', is_spam=True),
#  Message(text='Ou Wei Lighting,Nights Will Be Lightening!\n', is_spam=True),
#  Message(text='[ILUG] °ӷ~줽ǥX\n', is_spam=True),
#  Message(text='Behind Every Elite Producer...\n', is_spam=True),
#  Message(text='found a secret link   ADV\n', is_spam=True),
#  Message(text='We Dare You to Find a Better Annuity\n', is_spam=True),
#  Message(text='Did I give you the money yet?          DLRA\n', is_spam=True),
#  Message(text='Adv: Mortgage Quotes Fast Online, No Cost\n', is_spam=True),
#  Message(text='Approved Online, Internet, Buy Viagra              SJHFL\n', is_spam=True),
#  Message(text='TEEN LESBIAN WEBSITE\n', is_spam=True),
#  Message(text='The Best Critical Illness Policy on the Market\n', is_spam=True),
#  Message(text='Guaranteed to lose 10-12 lbs in 30 days with Slim Patch                    10.24\n', is_spam=True),
#  Message(text='=?Big5?B?rEKq96SjrE5+fqdPtsykRn5+?=\n', is_spam=True),
#  Message(text='private\n', is_spam=True),
#  Message(text='hape up for summer now\n', is_spam=True),
#  Message(text='[ILUG] STOP THE MLM INSANITY\n', is_spam=True),
#  Message(text='Work at Home - $5000 a month\n', is_spam=True),
#  Message(text='You have been hand selected... Free Info!\n', is_spam=True),
#  Message(text='Get on the Bus.. gbvzzzz\n', is_spam=True),
#  Message(text='University Diplomas\n', is_spam=True),
#  Message(text='Free Shipping on all orders at Blair.com\n', is_spam=True),
#  Message(text='Life Insurance - Why Pay More?\n', is_spam=True),
#  Message(text='8 Free Movie Tickets for doing a 2 Minute survey! Any Movie, Any Theater!\n', is_spam=True),
#  Message(text='Your Shipment Status\n', is_spam=True),
#  Message(text='art Your Private Photo Album Online!                             13.200\n', is_spam=True),
#  Message(text='Make a Fortune On eBay                         24772\n', is_spam=True),
#  Message(text='Re: Super CHARGE your desktop or laptop today!     17639\n', is_spam=True),
#  Message(text='The Government Grants You $25,000!\n', is_spam=True),
#  Message(text='Free big cock in Pussy\n', is_spam=True),
#  Message(text='http://www.efi.ie/\n', is_spam=True),
#  Message(text='I just put my webcam on 4u hunnie=)\n', is_spam=True),
#  Message(text='ake advantage of this offer                24344\n', is_spam=True),
#  Message(text='NEW TECHNOLOGY - DIGITAL VIDEO RECORDER (Smart IP Technology)\n', is_spam=True),
#  Message(text='Immediate Reply Needed\n', is_spam=True),
#  Message(text='=?ISO-2022-JP?B?GyRCTCQ+NUJ6OS05cCIoPF5HLiEqPVAycSQkJE45LT5sGyhC?=\n', is_spam=True),
#  Message(text='Best Long Distance On the Net - 3.9 Cents With No Monthly Fees\n', is_spam=True),
#  Message(text='WORK FROM HOME.  WE ARE HIRING\n', is_spam=True),
#  Message(text='First Time Generic V*agra under $3 per 50mg\n', is_spam=True),
#  Message(text='$14.95 per year for .COM, .BIZ, and .INFO extensions\n', is_spam=True),
#  Message(text='Congratualtions zzzz8969 ! !!\n', is_spam=True),
#  Message(text='-> IN THE NEWS TODAY <----\n', is_spam=True),
#  Message(text='FW: SHORT TERM BUY RECOMMENDATION\n', is_spam=True),
#  Message(text='One Sale - Three Commission Streams\n', is_spam=True),
#  Message(text='Z-app the Competition with Roster\n', is_spam=True),
#  Message(text='Join & Get 4 DVDs for 49 ea. (+shipping & processing)! Details Inside...\n', is_spam=True),
#  Message(text='fwd:  NORTON SYSTEMWORKS CLEARANCE SALE!\n', is_spam=True),
#  Message(text='[ILUG-Social] please kindly get back to me\n', is_spam=True),
#  Message(text='Meet other Singles just like you\n', is_spam=True),
#  Message(text='Chicago Meeting Site\n', is_spam=True),
#  Message(text='A CRY FOR HELP\n', is_spam=True),
#  Message(text='Make $500 - $2500/Week on Ebay                     3352\n', is_spam=True),
#  Message(text="DON'T LET A COMPUTER VIRUS RUIN YOUR DAY!          12879\n", is_spam=True),
#  Message(text='Email marketing info\n', is_spam=True),
#  Message(text='NORTON SYSTEMWORKS 2002 CLEARANCE SALE! 6801wbRq4-940mJbj463-19\n', is_spam=True),
#  Message(text='New Version 7: Uncover the TRUTH about ANYONE!\n', is_spam=True),
#  Message(text='[ILUG-Social] HELLO\n', is_spam=True),
#  Message(text='=?GB2312?B?NTDUqrvxtcPSu9LazuXHp83yRU1BSUy12Na3tcS7+rvh?=\n', is_spam=True),
#  Message(text='A better investment than the stock market.\n', is_spam=True),
#  Message(text="Join the Web's Fastest Growing Singles Community                       14.51\n", is_spam=True),
#  Message(text='FREE Health Insurance Quotes\n', is_spam=True),
#  Message(text='Welcome to OfferClub!\n', is_spam=True),
#  Message(text='link to my webcam you wanted \n', is_spam=True),
#  Message(text='11th Convergence India 2003 exhibition & conference\n', is_spam=True),
#  Message(text='Hottest babes!                                                       4139YAEk3--9\n', is_spam=True),
#  Message(text='Too Busy Earning A Living To Make Any Money\n', is_spam=True),
#  Message(text='Attn: How about being a few pounds lighter?OLIBYKN\n', is_spam=True),
#  Message(text='Make Huge Profits on eBay                          951\n', is_spam=True),
#  Message(text='ADV: Extended Auto Warranties Here                                                   dhzbj\n', is_spam=True),
#  Message(text='nter Chinese market\n', is_spam=True),
#  Message(text='Make your prints beautiful & SAVE BIG!                 OYDQH\n', is_spam=True),
#  Message(text='Get the Computer Skills you need - Free\n', is_spam=True),
#  Message(text='Looking for property in SPAIN?\n', is_spam=True),
#  Message(text='[ILUG] HELLO\n', is_spam=True),
#  Message(text='Invite: Content Management Summit, Oct. 10th New York City\n', is_spam=True),
#  Message(text='Interest Rates at Forty Yr. Lows\n', is_spam=True),
#  Message(text="[ILUG] Join the Web's Fastest Growing Singles Community 11.67\n", is_spam=True),
#  Message(text='MULTIPLY YOUR CUSTOMER BASE!\n', is_spam=True),
#  Message(text='Attn: NORTON SYSTEMWORKS CLEARANCE SALE_ONLY $29.99!                  Y\n', is_spam=True),
#  Message(text='[ILUG-Social] re: Guaranteed to lose 10-12 lbs in 30 days 10.148\n', is_spam=True),
#  Message(text='Get your own fountain of youth! HGH human growth hormone from 21st Century!17441\n', is_spam=True),
#  Message(text='Commissions Too High to Publish\n', is_spam=True),
#  Message(text='Tell these cam sluts what to do\n', is_spam=True),
#  Message(text='[ILUG-Social] urgent assistance\n', is_spam=True),
#  Message(text='Market Internet Access - No Investment Needed \n', is_spam=True),
#  Message(text='Information for you\n', is_spam=True),
#  Message(text='[ILUG] Guaranteed to lose 10-12 lbs in 30 days 10.206\n', is_spam=True),
#  Message(text='Toners and inkjet cartridges for less....               NOAZ\n', is_spam=True),
#  Message(text='MSNBC: Rates Hit 35 year Low 4.75% ...12304\n', is_spam=True),
#  Message(text='[ILUG] Here is the information you requested\n', is_spam=True),
#  Message(text='One of a kind Money maker! Try it for free!\n', is_spam=True),
#  Message(text='[ILUG-Social] Claim Your $25 Kmart Gift Card\n', is_spam=True),
#  Message(text='Get your OWN piece of history.\n', is_spam=True),
#  Message(text='Poker for money againts real players\n', is_spam=True),
#  Message(text='A revolution in the PC world has arrived.          RSIRTR\n', is_spam=True),
#  Message(text='Teach and Grow Rich\n', is_spam=True),
#  Message(text='Re: Fw: User Name & Password to Membership To 5 Sites zzzz@example.com pviqg\n', is_spam=True),
#  Message(text='Grow Up And Be A Man! abm\n', is_spam=True),
#  Message(text='The DEBT-$AVER Program              SKYXTGM\n', is_spam=True),
#  Message(text="Wall Street's dirty little secret ...\n", is_spam=True),
#  Message(text='Funds Investment\n', is_spam=True),
#  Message(text='Plans for cable\n', is_spam=True),
#  Message(text='Attn: SYSTEMWORKS CLEARANCE SALE_ONLY $29.99                         12173\n', is_spam=True),
#  Message(text='ADV: Extended Auto Warranties Here hvgxs\n', is_spam=True),
#  Message(text='=?ISO-2022-JP?B?GyRCTCQ+NUJ6OS05cCIoPF5HLiEqPVAycSQkJE45LT5sGyhC?=\n', is_spam=True),
#  Message(text='Bay PowerSeller Secrets                         6826\n', is_spam=True),
#  Message(text='[ILUG] enter Chinese market\n', is_spam=True),
#  Message(text="ADV: Interest rates slashed! Don't wait!                                                   ccaxc\n", is_spam=True),
#  Message(text='[ILUG-Social] Everybody Gets Paid - No Recruiting Needed\n', is_spam=True),
#  Message(text='[ILUG] Best Replica Goods - Best Prices\n', is_spam=True),
#  Message(text='This one will make you money  9/20/02 11:34:52 PM\n', is_spam=True),
#  Message(text='Fw: VIRUS PROTECTION IS A MUST, YOU NEED SYSTEMWORKS! CPTJ\n', is_spam=True),
#  Message(text='[scoop] CEVIRI YAZILIMLARI\n', is_spam=True),
#  Message(text='[ILUG] Want to play poker with other people online.\n', is_spam=True),
#  Message(text='Expand Your business with our Money!\n', is_spam=True),
#  Message(text='Best Life Insurance, Lowest Cost...           NTICY\n', is_spam=True),
#  Message(text='--> DIRECT MARKETING WILL INCREASE SALES           23875\n', is_spam=True),
#  Message(text='MSNBC: Rates Hit 18 year Low 4.75% ...28940\n', is_spam=True),
#  Message(text='=?big5?Q?re:=A7=DA=AA=BE=B9D=A7A=BB=DD=ADn=A7=F3=A6h=BE=F7=B7|,=A4@=B0_=A8=D3=A7a!?=\n', is_spam=True),
#  Message(text='FW: Make Money Fast And Legal! As Seen on TV! 65000$+\n', is_spam=True),
#  Message(text='Re: Ink Prices Got You Down?              11956\n', is_spam=True),
#  Message(text='FREE WebBook Publishing Software - Download NOW!\n', is_spam=True),
#  Message(text='New Insurance Product - No Competition\n', is_spam=True),
#  Message(text='BIZ, .INFO, .COM for only $14.95\n', is_spam=True),
#  Message(text='*****SPAM*****\n', is_spam=True),
#  Message(text="Give Away FREE CD's - Earn $5K in 30 Days!\n", is_spam=True),
#  Message(text='=?iso-2022-jp?B?GyRCJDckOCRfJEgkYiRiJE4lMyVpJVwlbCE8JTclZyVzGyhK?=\n', is_spam=True),
#  Message(text='FREE HGH - Look 10 Years Younger in 3 Weeks!!!     HMUPRZD\n', is_spam=True),
#  Message(text='[ILUG] WE NEED YOUR ASSISTANCE TO INVEST IN YOUR COUNTRY\n', is_spam=True),
#  Message(text='Penile enlargement method - guaranteed !\n', is_spam=True),
#  Message(text='Online Doctors will fill your Viagra Prescription Now!!!                QEEB\n', is_spam=True),
#  Message(text='RE: Your Bank Account Information \n', is_spam=True),
#  Message(text='Get the Child Support You Deserve                      10.124\n', is_spam=True),
#  Message(text='Double Your Life Insurance at NO EXTRA COST!...               TCTOOM\n', is_spam=True),
#  Message(text='Collect Your Money! Time:1:30:33 AM\n', is_spam=True),
#  Message(text='Adult: Free Access\n', is_spam=True),
#  Message(text='**** American Millionaire Reveals His Secret Source of Wealth On The Internet!!!\n', is_spam=True),
#  Message(text='hipment Status\n', is_spam=True),
#  Message(text='Your Gateway to Wealth\n', is_spam=True),
#  Message(text='Never pay for porn again, YOUR FREE PAYSITE is here! 6277zwyL0-111bAgY1254IhZJ0-37-27\n', is_spam=True),
#  Message(text='Fw: Re: Account For Cum Shots To: zzzz@example.com OfferID: qxjx\n', is_spam=True),
#  Message(text='Online Doctors will fill your Viagra Prescription Now!!!                QEEB\n', is_spam=True),
#  Message(text='[ILUG] $4,000/Month with your PC ! NO SPAM ! PLEASE READ !\n', is_spam=True),
#  Message(text='ave 84% on CE Credits\n', is_spam=True),
#  Message(text='new extensions now only $14.95\n', is_spam=True),
#  Message(text='Testing a system, please delete\n', is_spam=True),
#  Message(text='Low Price Smokes\n', is_spam=True),
#  Message(text='zzzz,Your HGH Request!\n', is_spam=True),
#  Message(text='Over $100,000 Per Year Possible On The Net!  No Illegal MLM Junk! Time:11:43:57 PM\n', is_spam=True),
#  Message(text='!Gorgeous,Custom Websites - $349 Complete! (9009zRlD0-486vNhZ47@18)\n', is_spam=True),
#  Message(text='Introducing HGH: The Most Powerful Anti-Obesity Drug Ever\n', is_spam=True),
#  Message(text='=?big5?Q?=A7K=B6O=B5L=AD=AD=A6=B8=A5=F4=A5=B4=A4=A4=B4=E4=AA=F8=B3~=B9q=B8=DC?=\n', is_spam=True),
#  Message(text='Hit the Road with CNA\n', is_spam=True),
#  Message(text='6.50% Annuity w/4.05% Lifetime Bailout\n', is_spam=True),
#  Message(text='[ILUG] IMPORTANT.\n', is_spam=True),
#  Message(text='ADV: Lowest life insurance rates available!                                                   hsdpr\n', is_spam=True),
#  Message(text='Herbal Viagra 30 day trial....                CRUA\n', is_spam=True),
#  Message(text='Are you LOSING? The answer would amaze you!\n', is_spam=True),
#  Message(text='Last time you spent $25 did u make $100,000,s? Well this time you will. wju\n', is_spam=True),
#  Message(text='=?big5?Q?=A7A=B7=C7=B3=C6=A6n=A4F=B6=DC=3F?=\n', is_spam=True),
#  Message(text='FORTUNE 500 WORK AT HOME REPS NEEDED!\n', is_spam=True),
#  Message(text='Holidays are coming?\n', is_spam=True),
#  Message(text='Never pay eBay listing fees again!\n', is_spam=True),
#  Message(text='[WM] GREEN CARD CEKLS  KACIRMAYIN\n', is_spam=True),
#  Message(text="Newsletter Coach'Invest - Septembre 2002\n", is_spam=True),
#  Message(text='The TBA Doctor Walks the Walk on Diabetes\n', is_spam=True),
#  Message(text='Free Merchant Account Information                XAXFT\n', is_spam=True),
#  Message(text='Best product for 2002\n', is_spam=True),
#  Message(text='ave now                     \n', is_spam=True),
#  Message(text='Not too old to put out!                   26792\n', is_spam=True),
#  Message(text="Don't get caught by rising interest rates.\n", is_spam=True),
#  Message(text='REQUEST FOR MUTUALLY BENEFITTING ENDEAVOUR.\n', is_spam=True),
#  Message(text='[ILUG] Get the Child Support You Deserve                     10.132\n', is_spam=True),
#  Message(text='WARNING: Your computer may contain a virus!\n', is_spam=True),
#  Message(text='ADV: Professional Teeth Whitening At Home!                                                   ovcnd\n', is_spam=True),
#  Message(text='Account zzzz@example.com\n', is_spam=True),
#  Message(text='The TBA Doctor Walks the Walk on Diabetes\n', is_spam=True),
#  Message(text='**urgent assistance**\n', is_spam=True),
#  Message(text='[ILUG] Earn 100.000$ in one year working at home\n', is_spam=True),
#  Message(text='Are you ready for 10/5/2002?\n', is_spam=True),
#  Message(text='New, easy to use web conferencing software\n', is_spam=True),
#  Message(text='The "Business-Owner Friendly" Pension Plan\n', is_spam=True),
#  Message(text='If You Dont... Your Competition Will!              7377\n', is_spam=True),
#  Message(text='[ILUG] AWARD NOTIFICATION\n', is_spam=True),
#  Message(text='Place Your LTC Declines with Us\n', is_spam=True),
#  Message(text='FORTUNE 500 COMPANY HIRING, AT HOME REPS.\n', is_spam=True),
#  Message(text='zzzz,All New! Breast Enhancement\n', is_spam=True),
#  Message(text='URGENT ASSISTANCE(CONFIDENTIAL)\n', is_spam=True),
#  Message(text='Attn: How about being a few pounds lighter?OLIBYKN\n', is_spam=True),
#  Message(text='Teach and Grow Rich\n', is_spam=True),
#  Message(text='Impaired Risk Case of the Month\n', is_spam=True),
#  Message(text='Want to play poker with other people online.\n', is_spam=True),
#  Message(text='Re: Instant Quote\n', is_spam=True),
#  Message(text='FREE TRIAL - Last Stock pick UP 309%................................................. cqhcp\n', is_spam=True),
#  Message(text='Customized Warez CDs\n', is_spam=True),
#  Message(text="ADV: Interest rates slashed! Don't wait!                                                   xoxun\n", is_spam=True),
#  Message(text='YOUR ANTICIPATED ASSISTANT IS REQUIRED.\n', is_spam=True),
#  Message(text='60 minute free porn movie\n', is_spam=True),
#  Message(text='.. kennst mich noch ? nehrb\n', is_spam=True),
#  Message(text='FORTUNE 500 COMPANY HIRING, AT HOME REPS.\n', is_spam=True),
#  Message(text='Order your Viagra and weight-loss here 6117kFvc5--9\n', is_spam=True),
#  Message(text='I NEED AN URGENT CAPABLE ASSISTANCE.TEL:+225 05775748\n', is_spam=True),
#  Message(text='Fw: PROTECT YOUR COMPUTER,YOU NEED SYSTEMWORKS!DGYWAOG\n', is_spam=True),
#  Message(text='Re: What a night!\n', is_spam=True),
#  Message(text='Earn 100.000$ in one year working at home\n', is_spam=True),
#  Message(text='Mortgage Rates Are Down.                    ptjti\n', is_spam=True),
#  Message(text='Impaired Risk Case of the Month\n', is_spam=True),
#  Message(text='=?big5?Q?=A4=A3=AC=DD=B7|=AB=E1=AE=AC?=\n', is_spam=True),
#  Message(text='Best news yet\n', is_spam=True),
#  Message(text='Wanna see me get fisted?\n', is_spam=True),
#  Message(text="Have you planned for your family's future?         ZBM\n", is_spam=True),
#  Message(text='investment\n', is_spam=True),
#  Message(text='WebDesignHQ Newsletter\n', is_spam=True),
#  Message(text='[SAtalk] **urgent assistance**\n', is_spam=True),
#  Message(text='LIE`S, MIS-INFORMATION and FRAUD\n', is_spam=True),
#  Message(text='Advance Your Career and Find a Great Job!\n', is_spam=True),
#  Message(text='Take Advantage of Viral Marketing\n', is_spam=True),
#  Message(text='[]  ߴ  Best 5 & ڰ  ǳ\n', is_spam=True),
#  Message(text='Go get em gadgets of 2002 4497VLNz2--9\n', is_spam=True),
#  Message(text='[ILUG-Social] Need a Credit Card?\n', is_spam=True),
#  Message(text="ave $30k even if you've refi'd           1090\n", is_spam=True),
#  Message(text='Private Label Reseller Hosting  -  Expires 9/30/2002\n', is_spam=True),
#  Message(text='Half Price Cigarettes and Tobacco\n', is_spam=True),
#  Message(text='*Do Your Butt, Hips And Thighs Embarrass You?*\n', is_spam=True),
#  Message(text='[ILUG-Social] re: how to register one of the new domain extensions\n', is_spam=True),
#  Message(text="I'm ready to bare for you!\n", is_spam=True),
#  Message(text='Discount Smokes\n', is_spam=True),
#  Message(text='Incredible Pictures!!!!!!!!\n', is_spam=True),
#  Message(text='[ILUG-Social] my webcam is on babe!\n', is_spam=True),
#  Message(text='[ILUG] Garden Ornaments | mvcmv\n', is_spam=True),
#  Message(text='Attn:Targeted email addresses\n', is_spam=True),
#  Message(text='Better Sex for $2.99 until 08/26/2002 !!!!\n', is_spam=True),
#  Message(text='fwd:  NORTON SYSTEMWORKS CLEARANCE SALE_ONLY $29.99 7126kyiK0-697yFCQ4277rqZm-24\n', is_spam=True),
#  Message(text='$10 a hour for watching e-mmercials! No joke!\n', is_spam=True),
#  Message(text='[ILUG-Social] Low Price Tobacco\n', is_spam=True),
#  Message(text='Funds Investment\n', is_spam=True),
#  Message(text='FW: FOCUS ON VALUE\n', is_spam=True),
#  Message(text='fwd:  SYSTEMWORKS CLEARANCE SALE_ONLY $29.99\n', is_spam=True),
#  Message(text='FW: Washington wire\n', is_spam=True),
#  Message(text='Competitive Mortgage Rates\n', is_spam=True),
#  Message(text='Tired of paying big bucks for cable\n', is_spam=True),
#  Message(text='ADV: Extended Auto Warranties Here vfafu\n', is_spam=True),
#  Message(text='you can watch me\n', is_spam=True),
#  Message(text='NEED TO FIND SOMETHING?\n', is_spam=True),
#  Message(text='ill looking for a house?\n', is_spam=True),
#  Message(text="don't proscrastinate...it's only $14.95 per year\n", is_spam=True),
#  Message(text='Wir suchen Erotikdarsteller!\n', is_spam=True),
#  Message(text='Is Your Family Protected?\n', is_spam=True),
#  Message(text='shop your loan to lenders for the best rate        OTQ\n', is_spam=True),
#  Message(text='Re: Your bank account\n', is_spam=True),
#  Message(text='=?big5?Q?re:=B7Q=ADn=ADP=B4I,=A7A=C1=D9=ADn=B5=A5=A6h=A4[?=\n', is_spam=True),
#  Message(text='Look What Sandy is Doing in her DORM!!\n', is_spam=True),
#  Message(text='ADV: Internet marketing & communications; earn $100k/year... uleio\n', is_spam=True),
#  Message(text='You can gain from lowest interest rates in 30 years\n', is_spam=True),
#  Message(text='xabenteuer gefllig?\n', is_spam=True),
#  Message(text='Incredible Pictures!!!!!!!!\n', is_spam=True),
#  Message(text='Adv: Mortgage Quotes Fast Online, No Cost\n', is_spam=True),
#  Message(text='Printer Cartridges as low as $1.21 each!\n', is_spam=True),
#  Message(text='Play a Hilarious Phone Prank\n', is_spam=True),
#  Message(text='pecial Affiliate Offers from Amazon.Com!\n', is_spam=True),
#  Message(text='[ILUG] ASSISTANCE\n', is_spam=True),
#  Message(text='Bay, Be Debt Free by 2003!                      8119\n', is_spam=True),
#  Message(text='Attn: NORTON SYSTEMWORKS 2002 BLOWOUT!                 QHZHC\n', is_spam=True),
#  Message(text='How many "inches" do you need to satisfy a woman in bed?\n', is_spam=True),
#  Message(text='Yeni srmde\n', is_spam=True),
#  Message(text='Membership Renewal\n', is_spam=True),
#  Message(text='Hi,  Low price  inkjet cartridges bvax\n', is_spam=True),
#  Message(text='future business Ѻس!\n', is_spam=True),
#  Message(text='FWD:Direct marketing is working                16889\n', is_spam=True),
#  Message(text='Plans for cable\n', is_spam=True),
#  Message(text='Order your Viagra and weight-loss here 6117kFvc5--9\n', is_spam=True),
#  Message(text='Have You Dreamed Of Your Own Home Based Business?       eIExvv\n', is_spam=True),
#  Message(text='[ILUG] please kindly get back to me\n', is_spam=True),
#  Message(text='Huge natural tits\n', is_spam=True),
#  Message(text='zzzz, Is Your web Site Making Money! 2:18:15 PM 8/25/2002\n', is_spam=True),
#  Message(text='FREE Cell Phone + $50 Cash Back!\n', is_spam=True),
#  Message(text='ADV:  Harvest lots of E-mail addresses quickly !\n', is_spam=True),
#  Message(text='Re:[1]Save over $70 on this exquisite software suite. FTS\n', is_spam=True),
#  Message(text='A CRY FOR HELP\n', is_spam=True),
#  Message(text='Guaranteed to lose 10-12 lbs in 30 days                          11.150\n', is_spam=True),
#  Message(text='CAREER OPPORTUNITY.  WORK FROM HOME\n', is_spam=True),
#  Message(text='Tell Me Where to Send Your Health Card\n', is_spam=True),
#  Message(text='The Best Just Got Better\n', is_spam=True),
#  Message(text='^^^^^Cell Phone Belt Clips $1.95^^^^^^                           18070\n', is_spam=True),
#  Message(text="** You're -Approved-!\n", is_spam=True),
#  Message(text='=?GB2312?B?0rvN+KGwu92hsczsz8KjrNK71bnM7M/C1qotLS0tMjAwM8TqNNTCMcjVLS00?=\n', is_spam=True),
#  Message(text='Re: Hi\n', is_spam=True),
#  Message(text='Congratulations on Your 6 New Signups\n', is_spam=True),
#  Message(text='Re: PROTECT YOUR COMPUTER AGAINST HARMFUL VIRUSES! 21198\n', is_spam=True),
#  Message(text="What Warren Buffett won't tell ya ...\n", is_spam=True),
#  Message(text='Internet News Feeds for Executives dfvht\n', is_spam=True),
#  Message(text='[ILUG] BANK ERROR IN YOUR FAVOR\n', is_spam=True),
#  Message(text='Custom Warez CDs\n', is_spam=True),
#  Message(text='Teach and Grow Rich\n', is_spam=True),
#  Message(text='Faeries\n', is_spam=True),
#  Message(text='Re: This Weekend\n', is_spam=True),
#  Message(text='Free Excerpt;  Baby Makers, Loser Choosers, & Welfare Abusers...Images of My America!\n', is_spam=True),
#  Message(text='$250,000... as low as $6.50 per month.             edahx\n', is_spam=True),
#  Message(text='FORTUNE 500 COMPANY HIRING, AT HOME REPS.\n', is_spam=True),
#  Message(text='CyberAge Dating - Invitation from Jenny\n', is_spam=True),
#  Message(text='ADV: Lowest life insurance rates available!                                                   pzcby\n', is_spam=True),
#  Message(text='Re: You want sex? 7099ocYT9-261UccU3485gGCz0-11-27\n', is_spam=True),
#  Message(text='re:  SYSTEMWORKS CLEARANCE SALE_ONLY $29.99 0989sqJ-7\n', is_spam=True),
#  Message(text='Lenders WILL COMPETE for your mortgage             IVX\n', is_spam=True),
#  Message(text='king Your Partnership\n', is_spam=True),
#  Message(text='[ILUG] assistance needed\n', is_spam=True),
#  Message(text='Hgh: safe and effective release of your own growth hormone!30543\n', is_spam=True),
#  Message(text='Membership Status Notification\n', is_spam=True),
#  Message(text='Business Proposal.\n', is_spam=True),
#  Message(text='Toners and inkjet cartridges for less....          BSJMCOIK\n', is_spam=True),
#  Message(text='ADV: Are you protected? Free Life Insurance quote oefik\n', is_spam=True),
#  Message(text='MSNBC: Rates Hit 35 year Low 4.75% ...12304\n', is_spam=True),
#  Message(text='Never pay for the goodz again (8SimUgQ)\n', is_spam=True),
#  Message(text='We Buy Renewal Commissions\n', is_spam=True),
#  Message(text='The Flight to Safety is Upon Us\n', is_spam=True),
#  Message(text='[ILUG] Create a PAYCHECK with your COMPUTER and Enjoy Cheap ISP & shopping Discount.\n', is_spam=True),
#  Message(text='FriendSearch and zzzzason.org Partnership\n', is_spam=True),
#  Message(text='Mothers you want to fuck\n', is_spam=True),
#  Message(text='Got plans tonight?\n', is_spam=True),
#  Message(text='Fwd: Norton makes the BEST software available, now ONLY $29.99! 32053\n', is_spam=True),
#  Message(text='Life Insurance Quotes Without the Hassle...            JHIWNS\n', is_spam=True),
#  Message(text='Attn: NORTON SYSTEMWORKS 2002 CLEARANCE SALE!              VOJTGT\n', is_spam=True),
#  Message(text='Memory loss?\n', is_spam=True),
#  Message(text='Iraq Today Daily News - FREE Trial\n', is_spam=True),
#  Message(text='English Well for you?\n', is_spam=True),
#  Message(text='zzzz,Hello\n', is_spam=True),
#  Message(text='ADV: Lowest Rates Available on Term Life - Free Quote                                                   ihsxq\n', is_spam=True),
#  Message(text='Get the Child Support You Deserve                            11.180\n', is_spam=True),
#  Message(text='More cash for the business you already write - IMMEDIATELY\n', is_spam=True),
#  Message(text='Lease Deal\n', is_spam=True),
#  Message(text='zzzz,Increase your breast size. 100% safe!\n', is_spam=True),
#  Message(text='Best product for 2002\n', is_spam=True),
#  Message(text='Fw: NORTON SYSTEMWORKS 2002 CLEARANCE SALE!        11058\n', is_spam=True),
#  Message(text='[ILUG] (no subject)\n', is_spam=True),
#  Message(text='=?iso-2022-jp?B?GyRCJDckOCRfJEgkYiRiJE4lMyVpJVwlbCE8JTclZyVzGyhK?=\n', is_spam=True),
#  Message(text='$250,000 for only $6.50 per month.                    qkdjtqsscr\n', is_spam=True),
#  Message(text='New Stock Pick: BBAN - Last Pick UP 309%.......................................... gsg\n', is_spam=True),
#  Message(text='ometimes Less is More...\n', is_spam=True),
#  Message(text='Low Cost Easy to Use Conferencing\n', is_spam=True),
#  Message(text='Conference calls/best quality/$.18 per minute!\n', is_spam=True),
#  Message(text='[ILUG] MICHAEL ! ilug\n', is_spam=True),
#  Message(text='[]  ߴ  Best 5 & ڰ  ǳ\n', is_spam=True),
#  Message(text='Look What Sandy is Doing in her DORM!!\n', is_spam=True),
#  Message(text='PROTECT YOUR INFORMATION AND YOUR COMPUTER\n', is_spam=True),
#  Message(text='=?ISO-2022-JP?B?GyRCTCQ+NUJ6OS05cCIoPF5HLiEqPVAycSQkJE45LT5sGyhC?=\n', is_spam=True),
#  Message(text='I was so scared... my very first DP\n', is_spam=True),
#  Message(text='Low cost quality conference calls\n', is_spam=True),
#  Message(text='Re:[1]Save over $70 on this exquisite software suite. 32004\n', is_spam=True),
#  Message(text='[WM] greencard 2004 ekiliini karmayn\n', is_spam=True),
#  Message(text='How would you like to create your own DVD library? 4863d-5\n', is_spam=True),
#  Message(text='$14.95 per year domain names\n', is_spam=True),
#  Message(text='online catalog of articles, adult toys 2009vjtt6-179dML-15\n', is_spam=True),
#  Message(text='zzzz, do we have your money?\n', is_spam=True),
#  Message(text='Re: Your VIP Pass\n', is_spam=True),
#  Message(text="Pru Life's UL Portfolio Rocks\n", is_spam=True),
#  Message(text='Guaranteed Best Mortgage Rate\n', is_spam=True),
#  Message(text='[ILUG] Do NOT Drop your Life Insurance\n', is_spam=True),
#  Message(text="you don't satisfy me               FGTPRIL\n", is_spam=True),
#  Message(text='Re: Your bank account\n', is_spam=True),
#  Message(text='[scoop] Haberdar olun\n', is_spam=True),
#  Message(text='Have tax problems?\n', is_spam=True),
#  Message(text='- Custom Websites for $399 Complete! (1709D@5)\n', is_spam=True),
#  Message(text='your Company sales sky rocket.                 4611\n', is_spam=True),
#  Message(text='ADV: Lowest life insurance rates available!                                                   moode\n', is_spam=True),
#  Message(text='NEWS.COM INVESTOR: Battered stocks regain ground\n', is_spam=False),
#  Message(text='[Lockergnome Tech Specialist]  Geothermal Caffeine\n', is_spam=False),
#  Message(text='Your Daily Dilbert 07/13/2002\n', is_spam=False),
#  Message(text='AOL Keyword: Fraud Probe\n', is_spam=False),
#  Message(text='FREE SHIPPING! No Minimum Purchase* at Buy.com\n', is_spam=False),
#  Message(text='Tribute MovieMail - Vol. 1 #48\n', is_spam=False),
#  Message(text='GOVERNMENT REGULATION IS KILLING THE STOCK MARKET\n', is_spam=False),
#  Message(text='[Lockergnome Penguin Shell]  Karaoke Kernel\n', is_spam=False),
#  Message(text='MEDIA: spamNEWS Digest September 30 - October 05, 2002\n', is_spam=False),
#  Message(text='DivX News: Battle of the Planets in DivX, Warcraft III, and the\n', is_spam=False),
#  Message(text='[Lockergnome Tech Specialist]  Handprint Singing\n', is_spam=False),
#  Message(text="Xscale disappoints in Toshiba's e740\n", is_spam=False),
#  Message(text='This week: Deck, Tex-Edit Plus, Boom\n', is_spam=False),
#  Message(text='Your Daily Dilbert 07/10/2002\n', is_spam=False),
#  Message(text='[ILUG-Social] Re: Important - reenactor insurance needed\n', is_spam=False),
#  Message(text="Cash Flow Doesn't Lie...Even After Today's Rally \n", is_spam=False),
#  Message(text='Why HP could be king of servers (Tech Update)\n', is_spam=False),
#  Message(text='Reg Headlines Tuesday July 16\n', is_spam=False),
#  Message(text="DayTips' Poem-a-Day: 09/13/02\n", is_spam=False),
#  Message(text="Apt repository authentication: it's time\n", is_spam=False),
#  Message(text="Next MS Office? Here's what I'd add--and delete [ANCHORDESK]\n", is_spam=False),
#  Message(text='The ISO17799 Newsletter - Issue 4\n', is_spam=False),
#  Message(text='[Lockergnome Penguin Shell]  Weekend Warriors\n', is_spam=False),
#  Message(text='Linux-Announce Digest #180\n', is_spam=False),
#  Message(text='[Lockergnome Windows Daily]  Beefier Vinyl\n', is_spam=False),
#  Message(text='CNET NEWS.COM: Copies, Webcasts tangled in draft bill\n', is_spam=False),
#  Message(text='[Lockergnome Apple Core]  Intuitive Cash\n', is_spam=False),
#  Message(text="Why we're changing our publishing schedule [ANCHORDESK]\n", is_spam=False),
#  Message(text='ave an extra $50 on the iPaq 3835 PDA (CNET SHOPPER)\n', is_spam=False),
#  Message(text="There's still time to enter Lifetime's New Season Sweeps!\n", is_spam=False),
#  Message(text='CNET NEWS.COM: File-traders in the crosshairs\n', is_spam=False),
#  Message(text='Looking for the perfect camera for your summer vacation? (CNET SHOPPER)\n', is_spam=False),
#  Message(text='JavaServer Pages updated\n', is_spam=False),
#  Message(text='[SQL] Database joins\n', is_spam=False),
#  Message(text='Personal Finance: Resolutions You Can Keep\n', is_spam=False),
#  Message(text='Geocaching.com Weekly Cache Notification\n', is_spam=False),
#  Message(text='WinXPnews: Time To Patch Your Windows Media Player\n', is_spam=False),
#  Message(text='This week: Browse or bust\n', is_spam=False),
#  Message(text='Astrology.com: daily horoscope\n', is_spam=False),
#  Message(text="Re: Hi! I'm new here.\n", is_spam=False),
#  Message(text='What you need for iPaq wireless connectivity (Tech Update)\n', is_spam=False),
#  Message(text='Your Daily Jump Start\n', is_spam=False),
#  Message(text='Red Hat Linux 8.0 now available on Red Hat Network\n', is_spam=False),
#  Message(text="Broadband ISPs wise up to wireless, defend (or don't) against hackers (CNET INTERNET SERVICES)\n", is_spam=False),
#  Message(text='On The Way to Telluride, On My Way Back to the World\n', is_spam=False),
#  Message(text='[Lockergnome Apple Core]  Skip Content\n', is_spam=False),
#  Message(text='hopping for an affordable gaming PC? (CNET SHOPPER)\n', is_spam=False),
#  Message(text='Personalize your Palm OS device\n', is_spam=False),
#  Message(text='[MLB-WIRELESS] FW: Cisco Wireless LAN Solutions\n', is_spam=False),
#  Message(text='Cordless phones: the other wireless devices\n', is_spam=False),
#  Message(text='(SPAM? 08.00) lists.sourceforge.net mailing list memberships reminder\n', is_spam=False),
#  Message(text='Get the most out of your games and graphics! (CNET SHOPPER)\n', is_spam=False),
#  Message(text='THE WEEK IN REVIEW: Harvest at Macworld\n', is_spam=False),
#  Message(text='Take all your music on the road (ZDNET SHOPPER)\n', is_spam=False),
#  Message(text='NEWS.COM INVESTOR: Techs fall again with telecoms, Dow drops below 8K\n', is_spam=False),
#  Message(text='[Lockergnome Tech Specialist]  Frequent Format\n', is_spam=False),
#  Message(text='EFFector 15.28: Motions Filed in Morpheus Peer-to-Peer Case,\n', is_spam=False),
#  Message(text='OURCEFORGE.NET UPDATE: August 14, 2002\n', is_spam=False),
#  Message(text='Reg Headlines Monday July 15\n', is_spam=False),
#  Message(text="Market Can't Find Its Bottom With Both Hands\n", is_spam=False),
#  Message(text='ptember Core Java Technologies Newsletter\n', is_spam=False),
#  Message(text='Cell phones coming soon\n', is_spam=False),
#  Message(text='[Lockergnome Windows Daily]  Dignity Shakedown\n', is_spam=False),
#  Message(text="When search results don't count (Tech Update)\n", is_spam=False),
#  Message(text="MS's Palladium: What the hell is it? (Here's what!) [ANCHORDESK]\n", is_spam=False),
#  Message(text='F2M - Ihre kostenlose Faxnummer - Newsletter\n', is_spam=False),
#  Message(text='[NOVICE] pl/pgsql and returns timestamp type\n', is_spam=False),
#  Message(text='Buy Ryanair Travel Insurance Today\n', is_spam=False),
#  Message(text='Your Daily Dilbert 07/22/2002\n', is_spam=False),
#  Message(text='Your Daily Dilbert 07/11/2002\n', is_spam=False),
#  Message(text='BUG REVIEW\n', is_spam=False),
#  Message(text='Core Java Technologies Tech Tips, September 10, 2002 (ArrayList vs. LinkedList, Zero-Length Arrays)\n', is_spam=False),
#  Message(text='Your Daily Dilbert 07/18/2002\n', is_spam=False),
#  Message(text='Personal laser picks for students, SOHO users, and more! (ZDNET SHOPPER)\n', is_spam=False),
#  Message(text="You're signed up for the Reich Report!\n", is_spam=False),
#  Message(text='CNET NEWS.COM: Canning spam without eating up real mail\n', is_spam=False),
#  Message(text="Classic Novels, Aesop's Fables, Issue 49\n", is_spam=False),
#  Message(text='Reg Headlines Friday July 19\n', is_spam=False),
#  Message(text='sting for taint.org, part 2\n', is_spam=False),
#  Message(text='This Week: FileSystem, AppletFile, PHP Master Editor\n', is_spam=False),
#  Message(text="Today's news: Serious PHP flaw found\n", is_spam=False),
#  Message(text='Reg Headlines Wednesday July 10\n', is_spam=False),
#  Message(text='This Weeks Movie Trivia Question from All Things New England\n', is_spam=False),
#  Message(text='CNET NEWS.COM: The tech side of homeland defense\n', is_spam=False),
#  Message(text='Dear Steve Jobs: At Macworld, show me this... [ANCHORDESK]\n', is_spam=False),
#  Message(text="Get the Perfect Mix of ZDNet's Best Stuff!\n", is_spam=False),
#  Message(text='[Lockergnome Digital Media]  Humblest Alarm\n', is_spam=False),
#  Message(text='EFFector 15.25: Judge Grants Consumer Voice in ReplayTV Lawsuit, Musician Endorses Music Sharing\n', is_spam=False),
#  Message(text='[Lockergnome Digital Media]  Clever Ritual\n', is_spam=False),
#  Message(text='ring multiple virtual hosts\n', is_spam=False),
#  Message(text='neak Peek: NEW HP Products\n', is_spam=False),
#  Message(text="hop smarter with ZDNet's price-feature analysis\n", is_spam=False),
#  Message(text='Your Daily Dilbert 07/19/2002\n', is_spam=False),
#  Message(text='Brother, Can You Spare a Jet?\n', is_spam=False),
#  Message(text='Geocaching.com Weekly Cache Notification\n', is_spam=False),
#  Message(text="Market Can't Find Its Bottom With Both Hands\n", is_spam=False),
#  Message(text='[Lockergnome Penguin Shell]  Recursive Metaphor\n', is_spam=False),
#  Message(text='CNET NEWS.CONTEXT: Adios to options excess?\n', is_spam=False),
#  Message(text='CNET NEWS.COM: Jobs touts OS X, iPods, iMac\n', is_spam=False),
#  Message(text='[Lockergnome Windows Daily]  Cranky Beats\n', is_spam=False),
#  Message(text="Wrox Press Developer's Journal\n", is_spam=False),
#  Message(text='CAUCE NEWS, Vol 6, No 2, June 2002\n', is_spam=False),
#  Message(text='CNET DIGITAL DISPATCH: Saying good-bye to free\n', is_spam=False),
#  Message(text='This week: Marine Aquarium, QuickTime, MoonDock\n', is_spam=False),
#  Message(text='Oracle Technology Network TechBlast - July 2002\n', is_spam=False),
#  Message(text='[Lockergnome Windows Daily]  Entrance Slouch\n', is_spam=False),
#  Message(text="CNET: Why I don't use firewalls\n", is_spam=False),
#  Message(text='GAMESPOT PC: Lionheart designer diary, No One Lives Forever 2 screenshot update, and more!\n', is_spam=False),
#  Message(text="Re: Hi! I'm new here.\n", is_spam=False),
#  Message(text='[Lockergnome Penguin Shell]  Retail Ready\n', is_spam=False),
#  Message(text='firewalls Digest V1 #33\n', is_spam=False),
#  Message(text='This Week: Chilkat Zip, Anfy Java, VB-PowerWrap\n', is_spam=False),
#  Message(text='pdated weblogs from blo.gs\n', is_spam=False),
#  Message(text='Neat Net Tricks Standard Issue 131 - August 15, 2002\n', is_spam=False),
#  Message(text='Reg Headlines Thursday July 11\n', is_spam=False),
#  Message(text='iSilo announcements (August 15, 2002)\n', is_spam=False),
#  Message(text='(SPAM? 08.00) lists.sourceforge.net mailing list memberships reminder\n', is_spam=False),
#  Message(text='Reg Headlines Thursday July 18\n', is_spam=False),
#  Message(text='NEWS.COM INVESTOR: Tech stocks drop again on Qwest criminal probe news\n', is_spam=False),
#  Message(text='Four free e-mailers reviewed, Get the gear you need to burn DVDs\n', is_spam=False),
#  Message(text='THE WEEK IN REVIEW: Quit copying\n', is_spam=False),
#  Message(text='CNET: A note to our subscribers\n', is_spam=False),
#  Message(text='Where TabletPC will succeed (Tech Update)\n', is_spam=False),
#  Message(text='Re: remove\n', is_spam=False),
#  Message(text='Canon USA Reseller News : July\n', is_spam=False),
# ...
#  Message(text='Re: [zzzzteana] The Cafe Forteana is back online!!!\n', is_spam=False),
#  Message(text='More fun with the PTC\n', is_spam=False),
#  Message(text='Hooters Air concept crashes and burns\n', is_spam=False),
#  Message(text='Re: [Razor-users] Razor with sendmail\n', is_spam=False),
#  Message(text='sylpheed-claws\n', is_spam=False),
#  Message(text='ChoolHouseRocks DVD\n', is_spam=False),
#  Message(text='Re: [zzzzteana] Save the planet, kill the people\n', is_spam=False),
#  Message(text='[SAtalk] Re: Custom actions for high scoring spam\n', is_spam=False),
#  Message(text='Native American economics (was Re: sed /s/United States/Roman\n', is_spam=False),
#  Message(text='Re: SunMSapple meta4 of the day\n', is_spam=False),
#  Message(text='Re: [Razor-users] "No razor servers available at this time"\n', is_spam=False),
#  Message(text='RE: liberal defnitions\n', is_spam=False),
#  Message(text='Two in court on IRA spy charges\n', is_spam=False),
#  Message(text='[ILUG] Hayes Accura ISDN PCI\n', is_spam=False),
#  Message(text='Human handshake opens data stream\n', is_spam=False),
#  Message(text='Nobel prize for British and US scientists\n', is_spam=False),
#  Message(text='[zzzzteana] White Horse vandalised\n', is_spam=False),
#  Message(text='Re: [ILUG] adsl router modem combo\n', is_spam=False),
#  Message(text='Kill Your Gods\n', is_spam=False),
#  Message(text='Archaeological finds show that the Incas rode dinosaurs, science\n', is_spam=False),
#  Message(text='Re: Canadians\n', is_spam=False),
#  Message(text='[Razor-users] Razor and Pine\n', is_spam=False),
#  Message(text='Re: Java is for kiddies\n', is_spam=False),
#  Message(text='Re: [SAtalk] O.T. Habeus -- Why?\n', is_spam=False),
#  Message(text='Re: [zzzzteana] The tenth planet\n', is_spam=False),
#  Message(text='[Spambayes] deleting "duplicate" spam before training?  good idea\n', is_spam=False),
#  Message(text='Re: Pluck and Luck\n', is_spam=False),
#  Message(text='[Spambayes] Re: [Python-Dev] Getting started with GBayes testing\n', is_spam=False),
#  Message(text='find the bug\n', is_spam=False),
#  Message(text='Monkey or man?\n', is_spam=False),
#  Message(text='Colophon 3\n', is_spam=False),
#  Message(text='Quickly\n', is_spam=False),
#  Message(text='"Free" Elvis Costello CD a trojan horse for DRM malware\n', is_spam=False),
#  Message(text='New Gunner Gilberto is quick to earn his stripes\n', is_spam=False),
#  Message(text='Fwd: Re[2]: AA Meetings the Hottest Place to Meet Women With Big\n', is_spam=False),
#  Message(text='[zzzzteana] Worryingly sophisticated bees\n', is_spam=False),
#  Message(text='Encryption approach to secure web applications\n', is_spam=False),
#  Message(text='Harvest Moon\n', is_spam=False),
#  Message(text='Movie Quiz\n', is_spam=False),
#  Message(text='The case for spam\n', is_spam=False),
#  Message(text="ven Levy's wireless neighbors\n", is_spam=False),
#  Message(text='[Spambayes] Deployment\n', is_spam=False),
#  Message(text='Re: dylsexics of the wrold, untie!\n', is_spam=False),
#  Message(text='[Spambayes] deleting "duplicate" spam before training?  good idea or\n', is_spam=False),
#  Message(text='Re: Internet Archive bookmobile\n', is_spam=False),
#  Message(text='RE: introductions\n', is_spam=False),
#  Message(text='MyIncErrors\n', is_spam=False),
#  Message(text='[zzzzteana] Latest Iraq-related news\n', is_spam=False),
#  Message(text='Re: [SAdev] Re: several messages\n', is_spam=False),
#  Message(text='RE: Selling Wedded Bliss (was Re: Ouch...)\n', is_spam=False),
#  Message(text='Re: The Wrong Business\n', is_spam=False),
#  Message(text='Re: The Big Jump\n', is_spam=False),
#  Message(text='Re: Selling Wedded Bliss (was Re: Ouch...)\n', is_spam=False),
#  Message(text='Blix told to await new orders on Iraq\n', is_spam=False),
#  Message(text='Re[2]: AA Meetings the Hottest Place to Meet Women With Big Bucks\n', is_spam=False),
#  Message(text='GDC 2002: Game Scripting in Python\n', is_spam=False),
#  Message(text='Re: RH 8 no DMA for DVD drive\n', is_spam=False),
#  Message(text='UFOs in the Sky!\n', is_spam=False),
#  Message(text="idekick's browser blows\n", is_spam=False),
#  Message(text="Rats' intestines and pigs' teeth\n", is_spam=False),
#  Message(text='RE: [ILUG] VPN implementation\n', is_spam=False),
#  Message(text='Re[2]: Selling Wedded Bliss (was Re: Ouch...)\n', is_spam=False),
#  Message(text='Re: Sorting\n', is_spam=False),
#  Message(text='Get your own genome, feed your hypochondria\n', is_spam=False),
#  Message(text='Re: Electric car an Edsel...\n', is_spam=False),
#  Message(text='Re: lifegem\n', is_spam=False),
#  Message(text='alsa-driver rebuild fails with undeclared USB symbol\n', is_spam=False),
#  Message(text='Re: --with ...\n', is_spam=False),
#  Message(text='Re: Selling Wedded Bliss (was Re: Ouch...)\n', is_spam=False),
#  Message(text='Re: Holidays for freshrpms.net :-)\n', is_spam=False),
#  Message(text='Re: Sorting\n', is_spam=False),
#  Message(text='Re: ARRRGHHH Had GPG working, now it doesnt.\n', is_spam=False),
#  Message(text='ru stupid\n', is_spam=False),
#  Message(text='Accessibility watershed?\n', is_spam=False),
#  Message(text='Netscape 7 Review\n', is_spam=False),
#  Message(text='Re: exmh bug?\n', is_spam=False),
#  Message(text='kinny Acoustic Bass\n', is_spam=False),
#  Message(text='Re: exmh bug?\n', is_spam=False),
#  Message(text='o the courthouse\n', is_spam=False),
#  Message(text="Postmortem: Ubi Soft China's Music Up -- Summer Rainbow\n", is_spam=False),
#  Message(text='Re[2]: Oh my...\n', is_spam=False),
#  Message(text='Re: Linking message [was: Re: Patch to complete a change...]\n', is_spam=False),
#  Message(text='Re: alsa-driver.spec tweak for homemade kernels\n', is_spam=False),
#  Message(text='Re: [Razor-users] Collision of hashes?\n', is_spam=False),
#  Message(text='[IRR] [dgc.chat] First public release of NeuDist Distributed\n', is_spam=False),
#  Message(text='TheThresher\n', is_spam=False),
#  Message(text='Google? Not in China\n', is_spam=False),
#  Message(text='[Spambayes] spambayes package?\n', is_spam=False),
#  Message(text='Re: [zzzzteana] Re: That wacky imam\n', is_spam=False),
#  Message(text='Re: apt and a hybrid system\n', is_spam=False),
#  Message(text='Automated forwarding\n', is_spam=False),
#  Message(text='Doom 3\n', is_spam=False),
#  Message(text='Re: CVS report\n', is_spam=False),
#  Message(text='Tate unveils its biggest work\n', is_spam=False),
#  Message(text='Encryption approach to secure web applications\n', is_spam=False),
#  Message(text='West Nile vaccine "in three years"\n', is_spam=False),
#  Message(text='RE: MIT OpenCourseWare\n', is_spam=False),
#  Message(text='Re: RH 8 no DMA for DVD drive\n', is_spam=False),
#  Message(text='Rendering the Great Outdoors: Fast Occlusion Culling for Outdoor\n', is_spam=False),
#  Message(text='Fuzzy Math\n', is_spam=False),
#  Message(text='Re: New Sequences Window\n', is_spam=False),
#  Message(text='Re: [Webdev] mod_usertrack\n', is_spam=False),
#  Message(text='Designer\'s Notebook: Stop Calling Games "Addictive"!\n', is_spam=False),
#  Message(text='Re: traceback in new exmh\n', is_spam=False),
#  Message(text='Re: RH 8 no DMA for DVD drive\n', is_spam=False),
#  Message(text='RE: [SAtalk] O.T. Habeus -- Why?\n', is_spam=False),
#  Message(text='xine src package\n', is_spam=False),
#  Message(text='Computational Recreations\n', is_spam=False),
#  Message(text='Jeremy Zawodny on life in Silicon Valley: "I came out here to\n', is_spam=False),
#  Message(text="[SAdev] [Bug 1006] Spamassassin's build process makes packaging\n", is_spam=False),
#  Message(text='Blair apologises for exam fiasco\n', is_spam=False),
#  Message(text='Re: [ILUG] Retrieving read mail from webmail.eircom.net via POP ?\n', is_spam=False),
#  Message(text='Re: Java is for kiddies\n', is_spam=False),
#  Message(text="[SAdev] [Bug 1046] Errors from 'perl Makefile.PL'\n", is_spam=False),
#  Message(text='[Spambayes] deleting "duplicate" spam before training?  good idea\n', is_spam=False),
#  Message(text='Re: [SAtalk] Reject, Blackhole, or Fake No-User\n', is_spam=False),
#  Message(text='At last, I have an excuse\n', is_spam=False),
#  Message(text='Re: [SAtalk] O.T. Habeus -- Why?\n', is_spam=False),
#  Message(text='RE: [SAtalk] user_prefs ignored\n', is_spam=False),
#  Message(text='Re: Wifi query\n', is_spam=False),
#  Message(text='never a cent\n', is_spam=False),
#  Message(text='There are four lights\n', is_spam=False),
#  Message(text='alsaplayer for (null)\n', is_spam=False),
#  Message(text='RE: Slaughter in the Name of God\n', is_spam=False),
#  Message(text='stomising FTOC display for specific folders...\n', is_spam=False),
#  Message(text='[use Perl] Stories for 2002-08-30\n', is_spam=False),
#  Message(text='kitty wants to play "eat your head"\n', is_spam=False),
#  Message(text='Re: [SAtalk] Re: patent on TMDA-like system\n', is_spam=False),
#  Message(text='[use Perl] Headlines for 2002-08-27\n', is_spam=False),
#  Message(text='Re: [SAdev] fully-public corpus of mail available \n', is_spam=False),
#  Message(text='RE: DataPower announces XML-in-silicon\n', is_spam=False),
#  Message(text='Oracle of Google\n', is_spam=False),
#  Message(text='Re: alsa-driver.spec tweak for homemade kernels\n', is_spam=False),
#  Message(text='Re: GA Development (was Re: [SAdev] [Bug 1030] NO_INVENTORY\n', is_spam=False),
#  Message(text='Football players addicted to video football\n', is_spam=False),
#  Message(text='Re: [Razor-users] Problem with Razor 2.14 and Spamassassin 2.41\n', is_spam=False),
#  Message(text='Re: [SAdev] testing with less rules\n', is_spam=False),
#  Message(text='Pix from Austin\n', is_spam=False),
#  Message(text='ATT Wireless Location tracking\n', is_spam=False),
#  Message(text='Carcooning\n', is_spam=False),
#  Message(text='[use Perl] Headlines for 2002-09-01\n', is_spam=False),
#  Message(text='Re: New Sequences Window\n', is_spam=False),
#  Message(text='[SAdev] [Bug 828] spamassassin.org is unreliable\n', is_spam=False),
#  Message(text='[SAdev] [Bug 1053] IMG tag based rules\n', is_spam=False),
#  Message(text='Re: Automated forwarding\n', is_spam=False),
#  Message(text='Re: --with ...\n', is_spam=False),
#  Message(text='[Spambayes] spambayes package?\n', is_spam=False),
#  Message(text='Re: [Razor-users] early experiences with Razor2 (and SA)\n', is_spam=False),
#  Message(text='Re: exmh bug?\n', is_spam=False),
#  Message(text='Re: ALSA Problem with Null kernel\n', is_spam=False),
#  Message(text='Re: [ILUG] find the biggest file\n', is_spam=False),
#  Message(text='Re: How unlucky can you get?\n', is_spam=False),
#  Message(text='Re: [zzzzteana] Not a materialisation, but a transfiguration\n', is_spam=False),
#  Message(text='Re: Anolther sequence related traceback\n', is_spam=False),
#  Message(text='Re: [SAtalk] False Positive of the Week\n', is_spam=False),
#  Message(text='Re: ALSA (almost) made easy\n', is_spam=False),
#  Message(text='Re: A moment of silence for the First Amendment (fwd)\n', is_spam=False),
#  Message(text='Re: Linking message [was: Re: Patch to complete a change...]\n', is_spam=False),
#  Message(text='Duct-tapers -- suspension and bondage fetish goes mainstream\n', is_spam=False),
#  Message(text='[zzzzteana] The new Steve Earle\n', is_spam=False),
#  Message(text='Re: [SAdev] 2.41 release? \n', is_spam=False),
#  Message(text='Re: asynchronous I/O (was Re: Gasp!)\n', is_spam=False),
#  Message(text='Re: patent on TMDA-like system\n', is_spam=False),
#  Message(text='Re: Selling Wedded Bliss (was Re: Ouch...)\n', is_spam=False),
#  Message(text="Lance Knobel of Davos Newbies does a quick review of Tony Blair's\n", is_spam=False),
#  Message(text='Apple Sauced...again\n', is_spam=False),
#  Message(text='[Spambayes] testing results\n', is_spam=False),
#  Message(text='Re: [VoID] a new low on the personals tip...\n', is_spam=False),
#  Message(text='a problem with apt-get\n', is_spam=False),
#  Message(text='[SACVS] CVS: spamassassin procmailrc.example,1.3,1.3.2.1\n', is_spam=False),
#  Message(text='ActiveBuddy\n', is_spam=False),
#  Message(text='[zzzzteana] A New Theory on Mapping the New World\n', is_spam=False),
#  Message(text='Re: [zzzzteana] Nothing like mama used to make\n', is_spam=False),
#  Message(text='Re: Apple Sauced...again\n', is_spam=False),
#  Message(text='Re: Selling Wedded Bliss (was Re: Ouch...)\n', is_spam=False),
#  Message(text='Re: [ILUG] Using Normal IDE Device with a Dell Latitude CPx laptop\n', is_spam=False),
#  Message(text='Re: Sorting\n', is_spam=False),
#  Message(text='Troubled Royal Ballet eyes US director\n', is_spam=False),
#  Message(text="Re: SF Weekly's Ultimate SF Date lineup :-)\n", is_spam=False),
#  Message(text='RE: [zzzzteana] Moon over ocean\n', is_spam=False),
#  Message(text='Re: A biblical digression\n', is_spam=False),
#  Message(text='Re: [SAdev] results of scorer evaluation\n', is_spam=False),
#  Message(text='Mac OS X browsers\n', is_spam=False),
#  Message(text='Internet Archive bookmobile\n', is_spam=False),
#  Message(text='P2P slogans for EFF\n', is_spam=False),
#  Message(text='FYI - gone this weekend\n', is_spam=False),
#  Message(text='Re: New Sequences Window\n', is_spam=False),
#  Message(text='Re: Another sequences window nit\n', is_spam=False),
#  Message(text='Re: http://apt.nixia.no/\n', is_spam=False),
#  Message(text='Why marching is crucial\n', is_spam=False),
#  Message(text='hooting from the Hip: An Interview with Hip Tanaka\n', is_spam=False),
#  Message(text='[Spambayes] understanding high false negative rate\n', is_spam=False),
#  Message(text='Re: /home/dude\n', is_spam=False),
#  Message(text='[Spambayes] understanding high false negative rate\n', is_spam=False),
#  Message(text='idekick, your mobile blogging pal\n', is_spam=False),
#  Message(text='Re: apt 0.5.7 on RH 7.x\n', is_spam=False),
#  Message(text='[SACVS] CVS: spamassassin spamassassin.raw,1.68.2.12,1.68.2.13\n', is_spam=False),
#  Message(text='[zzzzteana] Punch bags filled with incontinence pads\n', is_spam=False),
#  Message(text='[zzzzteana] Hitler-style applicant welcomed by parties\n', is_spam=False),
#  Message(text='Re: [ILUG] eircoms adsl modems\n', is_spam=False),
#  Message(text='Re: Google? Not in China\n', is_spam=False),
#  Message(text='QOTD: Cigarettes, fast food, beer.\n', is_spam=False),
#  Message(text='Re: Java is for kiddies\n', is_spam=False),
#  Message(text='Re: ALSA (almost) made easy\n', is_spam=False),
#  Message(text='[SAtalk] Running SA as a user app?\n', is_spam=False),
#  Message(text='Re[3]: Selling Wedded Bliss (was Re: Ouch...)\n', is_spam=False),
#  Message(text='[zzzzteana] Re: Australian Catholic Kiddie Perv Steps Aside\n', is_spam=False),
#  Message(text='Re: Ouch...\n', is_spam=False),
#  Message(text='Re: Digital radio playlists are prohibited?!\n', is_spam=False),
#  Message(text='Apple Switch parodies\n', is_spam=False),
#  Message(text='Re: Slaughter in the Name of God\n', is_spam=False),
#  Message(text='Iowa: "There was frost outside this morning!"\n', is_spam=False),
#  Message(text="Re: Signers weren't angry young men  (was: Java is for kiddies)\n", is_spam=False),
#  Message(text='addam set to let inspectors in\n', is_spam=False),
#  Message(text='Photoshop Theme.. ways to smuggle weapons-grade Uranium .\n', is_spam=False),
#  Message(text='Digital service launches with 30 free channels\n', is_spam=False),
#  Message(text='Re: Slaughter in the Name of God\n', is_spam=False),
#  Message(text='"Free" Elvis Costello CD a trojan horse for DRM malware\n', is_spam=False),
#  Message(text='Re: CD player UI for toddlers\n', is_spam=False),
#  Message(text='EFnet #fork\n', is_spam=False),
#  Message(text='Re: sed /s/United States/Roman Empire/g\n', is_spam=False),
#  Message(text='US use of lie detector tests criticised\n', is_spam=False),
#  Message(text='Turning junk computers into activist gold\n', is_spam=False),
#  Message(text='[Spambayes] Deployment\n', is_spam=False),
#  Message(text='Re: Patch to complete a change...\n', is_spam=False),
#  Message(text='Re: [SAdev] 2.42 to come ?\n', is_spam=False),
#  Message(text='Re: A moment of silence for the First Amendment (fwd)\n', is_spam=False),
#  Message(text='[ILUG] Flat rate is back lads!\n', is_spam=False),
#  Message(text='Blog de jeanpoole interviews Mark\n', is_spam=False),
#  ...]

# %%
# Split data into training and test data
import random
from scratch.machine_learning import split_data

random.seed(0)
train_messages, test_messages = split_data(data, 0.75)

model = NaiveBayesClassifier()
model.train(train_messages)

# %%
# Generate predictions

from collections import Counter 

predictions = [(message, model.predict(message.text))
              for message in test_messages]
confusion_matrix = Counter((message.is_spam, spam_probability >0.5)
                           for message, spam_probability in predictions)

print(confusion_matrix)
# Out:
# Counter({(False, False): 668, (True, True): 85, (True, False): 54, (False, True): 18})

# %% [markdown]
# - According to confusion matrix our model predicts:
#   > spam as spam = 85
#   > spam as ham = 54
#   > ham as ham = 668
#   > ham as spam = 18
#
#   > Precision = 85/(85+18) = 82%
#   > Recall = 85/(85+54) = 61%
#
# - Not bad for such a simple model where we are just focusing on subject of emails

# %%
# Let's see which words are most and least indicative of spam

def p_spam_given_token(token:str, model: NaiveBayesClassifier) -> float:
    prob_if_spam, prob_if_ham = model._probabilities(token)

    return prob_if_spam / (prob_if_ham + prob_if_spam)

words = sorted(model.tokens, key = lambda t: p_spam_given_token(t, model))
print("spammiest_words", words[-10:])
print("hammiest_words", words[:10])
# Out:
# spammiest_words ['assistance', '99', 'attn', 'sale', 'account', 'zzzz', 'money', 'systemworks', 'rates', 'adv']
# hammiest_words ['spambayes', '2', 'users', 'razor', 'zzzzteana', 'sadev', 'ouch', 'apt', 'bliss', 'wedded']

# %% [markdown]
# That's it!
#
# To get the better performance what can we do?
# - Look at the message content, not just the subject line. You’ll have to be careful how you deal with the message headers.
#
# - Our classifier takes into account every word that appears in the training set, even words that appear only once. Modify the classifier to accept an optional min_count threshold and ignore tokens that don’t appear at least that many times.
#
# - The tokenizer has no notion of similar words (e.g., cheap and cheapest). Modify the classifier to take an optional stemmer function that converts words to equivalence classes of words. For example, a really simple stemmer function might be:
# `def drop_final_s(word):`
#     `return re.sub("s$", "", word)`
#
#   Difficult - people use Porter stemmer - https://tartarus.org/martin/PorterStemmer/
#
# - Although our features are all of the form “message contains word wi,” there’s no reason why this has to be the case. In our implementation, we could add extra features like “message contains a number” by creating phony tokens like contains:number and modifying the tokenizer to emit them when appropriate.
